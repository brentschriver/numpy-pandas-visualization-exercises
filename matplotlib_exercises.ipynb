# %%
import matplotlib.pyplot as plt

x = range(10)
y = [num ** 2 - num + 2 for num in x]

plt.plot(x,y)
plt.annotate('(0,0)', xy = (0,0), xytext = (0,5))
# Out:
# Text(0, 5, '(0,0)')

# %%
x = range(10)
y1 = [num ** (1/2) for num in x]

plt.plot(x,y1)
plt.title('x^(1/2)')
# Out:
# Text(0.5, 1.0, 'x^(1/2)')

# %%
x = range(10)
y2 = [num ** 3 for num in x]

plt.plot(x,y2)
plt.title('$x^3$')
# Out:
# Text(0.5, 1.0, '$x^3$')

# %%
x = range(10)
y3 = [2 ** num for num in x]

plt.plot(x,y3)
plt.title('$2^x$')
# Out:
# Text(0.5, 1.0, '$2^x$')

# %%
x = range(10)
y4 = [1/(num + 1) for num in x]

plt.plot(x,y4)
plt.title('$\\frac{1}{x+1}$')
# Out:
# Text(0.5, 1.0, '$\\frac{1}{x+1}$')

# %%
x = range(10)
y1 = [num ** (1/2) for num in x]
y2 = [num ** 3 for num in x]
y3 = [2 ** num for num in x]
y4 = [1/(num + 1) for num in x]

plt.figure(figsize = (14,14))

plt.subplot(2,2,1)
plt.plot(x,y1)
plt.title('x^(1/2)')

plt.subplot(2,2,2)
plt.plot(x,y2)
plt.title('$x^3$')

plt.subplot(2,2,3)
plt.plot(x,y3)
plt.title('$2^x$')

plt.subplot(2,2,4)
plt.plot(x,y4)
plt.title('$\\frac{1}{x+1}$')
# Out:
# Text(0.5, 1.0, '$\\frac{1}{x+1}$')

# %%
x = range(10)
y1 = [num ** (1/2) for num in x]
y2 = [num ** 3 for num in x]
y3 = [2 ** num for num in x]
y4 = [1/(num + 1) for num in x]

plt.plot(x,y1)
plt.scatter(x,y1, color = 'r', label = '$\sqrt{x}$')
plt.plot(x,y2)
plt.scatter(x,y2, color = 'b', label = '$x^3$')
plt.plot(x,y3)
plt.scatter(x,y3, color = 'g', label = '$2^x$')
plt.plot(x,y4)
plt.scatter(x,y4, color = 'm', label = '$\\frac{1}{x+1}$')
plt.title('Four Different Functions')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
